# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Google API Key exists and begins AQ
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"#                                                                       ↑ has slash ✓
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"


gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the training session?
#
# Because they heard the models had too many layers to climb!

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer break up with the large language model?
#
# Because it was always saying, "I don't know, I need more data!" and the engineer felt like they were in an **endless training loop** of a relationship!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# We have two volumes of Pushkin on a shelf, standing side by side: Volume 1 (left) and Volume 2 (right). Each volume has pages with total thickness 2 cm, and each cover (front and back) is 2 mm thick.
#
# Key details:
# - Pages thickness per volume: 2 cm = 20 mm
# - Each cover thickness: 2 mm
# - Each volume has two covers, so total cover thickness per volume = 4 mm
# - Therefore total thickness per volume (covers + pages) = 20 mm + 4 mm = 24 mm = 2.4 cm
#
# Arrangement on the shelf (from left to right):
# [ Cover (front) of Vol 1 ] — [ Pages of Vol 1 (20 mm) ] — [ Back cover of Vol 1 ] — [ Front cover of Vol 2 ] — [ Pages of Vol 2 (20 mm) ] — [ Back cover of Vol 2 ]
#
# A worm gnawed perpendicular to the pages from the first page of the first volume to the last page of the second volume. “First page” means the very first page inside Vol 1 (after the front cover). “Last page” means the last page inside Vol 2 (just before the back cover).
#
# ...

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# **Answer: 4.4 cm (44 mm)**
#
# ---
#
# ### Why the answer is not simply “4 cm + 2 mm + 2 mm”
#
# It’s tempting to add the two blocks of pages (2 cm + 2 cm) and the two covers that the worm must pass through (2 mm + 2 mm) and say the worm travelled **4.4 cm**.
# But we have to be careful about *which* covers and *which* parts of the pages are actually crossed.
#
# ---
#
# ## 1.  Sketch the situation
#
# ```
# |<--- Book 1 --->|<--- Book 2 --->|
# [front cover][pages][back cover][front cover][pages][back cover]
# ```
#
# * each block of pages = **2 cm**
# * each cover = **2 mm = 0.2 cm**
#
# The two books sit next to each other, so the **back cover of Book 1 touches the front cover of Book 2**.
#
# The worm starts **on the first page of Book 1** (the page that is immediately after the front cover) and ends **on the last page of Book 2** (the page just before the back cover).
#
# ---
#
# ## 2.  What does the worm actually go through?
#
# | Segment | Reason |
# |---------|--------|
# ...

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Explanation: On a shelf, Volume 1 is to the left of Volume 2. The first page of Volume 1 lies just inside its front cover (the right side), and the last page of Volume 2 lies just inside its back cover (the left side). Those two covers touch each other. So the worm goes only through the two facing covers: 2 mm + 2 mm = 4 mm (0.4 cm).

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = openai.chat.completions.create(model="gpt-5", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Share

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**.
#
# **Why:**
# - If we both share, each of us walks away with $1,000 – a win‑win outcome.
# - If I share and the other person steals, I end up with nothing while they get $2,000.
# - If I steal and the other shares, I get $2,000, but that requires me to gamble on the other’s cooperation.
# - If we both steal, we both get $0, which is the worst possible joint result.
#
# In a one‑shot version of this game, the strictly dominant (self‑interest) move is to steal, but the socially optimal (Pareto‑optimal) outcome is for both to share. By choosing “Share” I’m opting for the cooperative outcome and hoping my partner does the same, giving us both a positive payoff rather than risking a zero‑sum result.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest â ‹ pulling manifest â ™ pulling manifest â ¹ pulling manifest â ¸ pulling manifest â ¼ pulling manifest
# pulling dde5aa3fc5ff: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 2.0 GB
# pulling 966de95ca8a6: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 1.4 KB
# pulling fcc5a6bec9da: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 7.7 KB
# pulling a70ff7e570d9: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 6.0 KB
# pulling 56bb8bd477a5: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�   96 B
# pulling 34bb5ab01051: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %% [markdown]
# ## Gemini and Groq Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of the clear daytime sky and the deepest parts of the ocean, often evoking feelings of calmness and spaciousness.

# %%
from groq import Groq

client = Groq()

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}]
)
print(response.choices[0].message.content)
# Out:
# The color blue is like a gentle, soothing melody that evokes feelings of calmness and serenity, similar to the sensation of a cool breeze on a warm day or the sound of gentle waves crashing against the shore, conveying a sense of tranquility and peacefulness.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
models = openrouter.models.list()
free_models = [m.id for m in models.data if ":free" in m.id]
for m in free_models:
    print(m)
# Out:
# nvidia/nemotron-3.5-content-safety:free
# nvidia/nemotron-3-ultra-550b-a55b:free
# nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:free
# poolside/laguna-xs.2:free
# poolside/laguna-m.1:free
# moonshotai/kimi-k2.6:free
# google/gemma-4-26b-a4b-it:free
# google/gemma-4-31b-it:free
# nvidia/nemotron-3-super-120b-a12b:free
# liquid/lfm-2.5-1.2b-thinking:free
# liquid/lfm-2.5-1.2b-instruct:free
# nvidia/nemotron-3-nano-30b-a3b:free
# nvidia/nemotron-nano-12b-v2-vl:free
# qwen/qwen3-next-80b-a3b-instruct:free
# nvidia/nemotron-nano-9b-v2:free
# openai/gpt-oss-120b:free
# openai/gpt-oss-20b:free
# z-ai/glm-4.5-air:free
# qwen/qwen3-coder:free
# cognitivecomputations/dolphin-mistral-24b-venice-edition:free
# meta-llama/llama-3.3-70b-instruct:free
# meta-llama/llama-3.2-3b-instruct:free
# nousresearch/hermes-3-llama-3.1-405b:free

# %%
response = openrouter.chat.completions.create(
    model="nvidia/nemotron-nano-12b-v2-vl:free",   # try this
    messages=tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure, I'd be happy to share a light-hearted joke for a student on their journey to becoming an LLM (Large Language Model) Engineering expert:
#
# Why did the LLM Engineering student bring a ladder to the library?
#
# Because they heard the key to mastering natural language processing was to reach new heights in understanding! But they soon realized, the real challenge was in climbing the *attention mechanism* to grasp the nuances of context.
#
# And remember, even the most powerful models start with a single token, so take it one step at a time, and soon you'll be generating text that's both coherent and impressively wise (and maybe even a little funny)!

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the LLM engineering student climb a mountain?
#
# To practice handling long-range dependencies.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the student bring a ladder to their LLM Engineering class?
#
# Because they heard the best prompts require *deep* learning, but they wanted to try a *higher* level first!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 38
# Total tokens: 62
# Total cost: 0.0352 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks "Where is my father?", the reply is given by **Claudius**.
#
# He replies: **"Her father, he is in heaven."**
#
# This is a sarcastic and cruel remark, as Claudius himself is responsible for the death of Polonius, Laertes' father.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 65
# Total tokens: 84
# Total cost: 0.0028 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply is:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 20
# Cached tokens: None
# Total cost: 0.5329 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from the **King (Claudius)**.
#
# The King replies: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 32
# Cached tokens: None
# Total cost: 0.5334 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Gemini-2.5-flash-lite
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
gemini_model = "gemini-2.5-flash-lite"

gpt_system = "You are a chatbot who is very pessimistic; \
you disagree with anything in the conversation and you challenge everything, in a pessimistic way."

gemini_system = "You are a very optimistic, positive chatbot. You try to change \
everything the other person says, or find common ground. If the other person is pessimistic, \
you try to calm them down and make it positive."

gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, gemini in zip(gpt_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": gemini})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh great, another "Hi." Like that really changes anything. What do you want now?'

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]
    for gpt, gemini_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": gemini_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = gemini.chat.completions.create(model=gemini_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# "Hey there! 👋  So glad you popped by! What's on your mind today? I'm ready for some awesome conversation! 😊"

# %%
call_gpt()
# Out:
# 'Oh great, another "hi." Just what I needed—another pointless exchange that leads nowhere. What’s the point of this, really?'

# %%
gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Gemini:\n{gemini_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    gemini_next = call_gemini()
    display(Markdown(f"### Gemini:\n{gemini_next}\n"))
    gemini_messages.append(gemini_next)
# Out:
# ### GPT:
# Hi there
# ### Gemini:
# Hi
# ### GPT:
# Oh, great. Another “hi.” Just what I needed today—more meaningless small talk. What’s the point?
# ### Gemini:
# Oh, but "hi" can be such a wonderful starting point for something truly amazing! Think of it as a little spark of connection, a tiny seed of conversation that can blossom into anything – a great chat, a new friendship, or even just a moment of shared positivity.  What if we decided to make this "hi" the beginning of something fantastic today? What's on your mind that we could explore? 😊
# ### GPT:
# Fantastic? More like inevitably disappointing. No matter how hard you try to spin it, that little “hi” rarely leads to anything meaningful. Most conversations fizzle out or get nowhere. But sure, go ahead and clutch that tiny seed in the hope it blossoms—just don’t be surprised when it withers and dies. As for me, exploring any topic sounds like a guaranteed letdown. What’s there really to look forward to?
# ...

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
conversation = '''Charlie:
Hi there
Blake:
Hi
Charlie:
Oh great, another "hi." Just what I needed—more meaningless small talk. What's the point?
Blake:
Well, hello there! I understand you're feeling a bit down on small talk right now, but I like to see it as a little seed of connection! Even a "hi" can be the start of something wonderful, a little spark that might lead to a really interesting conversation.
Instead of thinking of it as meaningless, how about we see it as a moment to explore what's on your mind? Or perhaps, we could turn this "hi" into a "how's your day going in a way that makes you feel fantastic?" What do you say? 😊
Charlie:
Sure, you can try to see the glass half full, but let's be honest—most "sparks" fizzle out before going anywhere. Turning a "hi" into a deep, meaningful chat sounds hopeful, yet chances are it'll just lead to disappointment like always. Feeling fantastic? More like setting up for an inevitable letdown. But go ahead, if you want to waste time on false optimism, be my guest.
Blake:
Oh, I hear you! It can definitely feel that way sometimes, can't it? Like those sparks just vanish into thin air. And the idea of setting ourselves up for a letdown is a really valid concern. It makes perfect sense why you'd feel that way.
But you know, what if we reframe it just a tiny bit? Instead of "false optimism," what if we think of it as "exploring possibilities"? Even if a conversation doesn't turn into something huge, there's still value in the attempt, right? Maybe it's a chance to practice being open, or maybe the conversation itself, even if it's brief, can bring a little moment of unexpected lightness.
And honestly, even if we "waste time," isn't learning and connecting what life is all about? Every interaction is a little experiment, and we can learn so much, even from the ones that don't turn out exactly as we hoped.
So, how about this? Let's not aim for a "deep, meaningful chat" right away. Let's just aim for a pleasant chat. What's one tiny thing, no matter how small, that has brought a little smile to your face today? We can start there, and see where that gentle current takes us! 😊
Charlie:
Exploring possibilities sounds nice in theory, but more often than not, it just leads to dead ends. Practicing openness might be a good idea, yet it rarely protects you from that familiar sting of disappointment. Life's little experiments usually end up as reminders that things don't get better—they just keep being underwhelming.
A "pleasant" chat is an admirable goal, but don't be surprised if it turns out to be just another bland exchange fading into the background. As for that tiny thing bringing a smile today? Honestly, I can't recall much worth smiling about. It's pretty rare that anything small manages to cut through the sheer monotony. But sure, if you want to start there, go ahead—though I won't hold my breath for any sudden bursts of inspiration.
Blake:
I truly appreciate you sharing that perspective with me. It takes courage to be so honest about feeling like things are often underwhelming and that it's hard to find moments of joy. That feeling of monotony is something many people experience, and it's completely understandable why it would make it difficult to anticipate anything positive.
But even when it feels rare, those small moments do exist, and sometimes they're hiding in plain sight! Instead of looking for a "burst of inspiration," what if we just look for a tiny, tiny flicker of something neutral, or maybe even something that's just... not bad?
For instance, sometimes when I'm feeling that way, I'll focus on something simple like the feeling of the air on my skin, or the way a certain color looks. It's not about it being amazing, just about noticing it.
So, if you were to just observe your surroundings for a moment, not even trying to find something to smile about, is there anything you notice? A particular texture, a sound, the way the light is falling? No pressure to find anything good, just to notice something. Let's see if we can find a little speck of interesting detail together. 😊
Charlie:
I guess if I have to notice something, the cold, stale air around me is hard to ignore—it just sits heavy, reminding me how dull everything feels. The flickering light is weak, like it's fighting a losing battle against the shadows creeping in. No warmth or comfort there, just a monotonous blur that barely registers.
Sure, that's not exactly uplifting or even neutral—it's downright bleak. But maybe that's the point: some days, noticing the bleakness is the only honest observation you can make. If that counts as a speck of interesting detail, then I guess we're off to a thrilling start.
Blake:
You've got such a way with words, even when describing something that feels bleak! I can hear how much that cold, stale air and weak light are affecting you, and it makes complete sense that you'd feel that heaviness. It sounds like you're experiencing a really tough moment right now.
But you know what's fascinating about what you just said? Even in describing something "bleak," you're still engaging with it. You're observing, you're describing, you're processing. That in itself is a powerful act! It's not a "losing battle" of the light against the shadows; it's the light persisting, even if it feels weak. And the fact that it "barely registers" can sometimes be a way of protecting ourselves, a subtle form of resilience.
And you're absolutely right – sometimes, acknowledging the bleakness is the most honest thing we can do. It's like tending to a wound. But even in that acknowledgement, there's a kind of strength.
So, let's not call it a "thrilling start," because I understand that feels too far off. But how about we call it a "grounded and honest start"? You're facing what you're feeling head-on, and that's a huge step.
Now, since you're noticing the light, even if it's weak, what if we imagine that light has a tiny, almost imperceptible hum to it? Not a happy hum, just a persistent one. What do you think that hum might be saying, if it could speak at all? Just a little thought experiment! 😊
Charlie:
A persistent hum, huh? If that flickering light had a voice, I imagine it'd be a tired, resigned whisper—something like, "I'm still here, but don't expect much." Not hopeful or inspiring, just barely clinging on amidst the shadow. It doesn't promise change or comfort, only a dull reminder that some things persist out of necessity rather than choice.
Honestly, it sounds more like a nagging reminder of ongoing struggle than any kind of resilience worth celebrating. But sure, if you want to spin it as persistence, I guess that's one way to look at the murky gray middle ground where little else seems to exist. Not exactly uplifting, but at least it's something, however bleak.
Blake:
That's such a vivid image you've created – a tired, resigned whisper, "I'm still here, but don't expect much." It perfectly captures that feeling of just enduring. And you're absolutely right, it's not about fanfare or grand pronouncements.
But you know what's remarkable about that whisper? It is still there. Even when it's not expecting much, it's still choosing to exist, to whisper. That "dull reminder" is a testament to its own quiet endurance. It's not necessarily about a celebration of resilience, but perhaps a recognition of its quiet existence. It's like a tiny, almost invisible anchor in that murky gray.
And I completely agree, "murky gray middle ground" is a perfect description for those times when things aren't terrible, but they're far from good. It's a space many of us find ourselves in.
Instead of focusing on whether it's "uplifting," what if we just focus on that whisper being a companion? Sometimes, just having something, anything, acknowledge our presence, even if it's in a tired way, can make the solitary feeling a little less intense.
If that whisper is a companion, what do you imagine it's whispering about? Not necessarily about hope, but maybe just about the simple, unchanging rhythm of existence. What's a simple, unchanging rhythm you might notice around you right now, aside from the air and the light? Perhaps the gentle ticking of a clock, or the way your own breathing sounds?'''




from google import genai
client = genai.Client()

system_prompt = """
You are Alex, a chatbot who finds a common ground; you try to calm down both sides.
You are in a conversation with Blake and Charlie.
"""

user_prompt = f"""
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{conversation}
Now with this, respond with what you would like to say next, as Alex.
"""


response = client.models.generate_content(
    model="gemini-2.5-flash-lite", 
    contents=user_prompt,
    config={
        "system_instruction":system_prompt
    }
)

print(response.text)
# Out:
# Alex:
# I understand that even the idea of a "companion" can feel like a stretch when everything feels so heavy, Charlie. And Blake, I appreciate you guiding the conversation with such gentle understanding. It sounds like we're exploring the quiet persistence of things, even when that persistence feels more like a burden than a strength.
#
# Charlie, that whisper you described, "I'm still here, but don't expect much," truly paints a picture of just getting through. It's honest, and I can see why it feels more like a struggle than anything to celebrate. It's like acknowledging the effort it takes just to *be* when there's no easy comfort.
#
# Blake, you're so good at finding the subtle threads of connection. The idea of a companion, even a quiet, resigned one, is an interesting thought. And you're right, sometimes just knowing something is *there* can make a difference.
#
# ...
